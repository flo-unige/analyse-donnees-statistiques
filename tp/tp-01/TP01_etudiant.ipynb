# %% [raw]
# ---
# title: "TP 1 — À compléter"
# author: "Prénom NOM"
# lang: fr
# format: typst
# ---

# %% [markdown]
# # Consignes provisoires
#
# Ce carnet réserve l’emplacement du TP 1. Remplacez le nom dans la cellule de configuration lorsque le TP sera utilisé.

# %%
# Le contenu Python du TP 1 sera ajouté ultérieurement.
print("Carnet provisoire du TP 1")

# %% [markdown]
# ## Réponse ouverte
#
# *Zone de réponse à remplacer lors de la conception du TP.*
